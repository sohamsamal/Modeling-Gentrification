# %% [markdown]
# ## Cellular Automata Modeling for Gentrification

# %%
# %load_ext autoreload
# %autoreload 2
# %pip install tk

from classes.Board import Board
from classes.utils import draw_board_features, draw_board_feature, draw_stacked_bar

import numpy as np
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
cell_features = [("H", np.int32),("PP", np.int32),("D", np.int32),("VS", np.float32)]
CA = Board(10, 10, cell_features, alpha=0.2, beta=0.5, gamma=0.1)
#CA.terminate()


for i in range(50):
    CA.update()
CA.terminate()

# %%
slider = draw_board_features(CA)
# Out:
# 0
# 0
# None
# None
# 51
# Axes(0.0644987,0.538745;0.236045x0.314727)
# 6
# Axes(0.539996,0.538745;0.236045x0.314727)
# 6
# Axes(0.0360823,0.1;0.236045x0.314727)
# 6
# Axes(0.511579,0.1;0.236045x0.314727)
# 6
# Axes(0.0644987,0.538745;0.236045x0.314727)
# 3
# Axes(0.539996,0.538745;0.236045x0.314727)
# 3
# Axes(0.0360823,0.1;0.236045x0.314727)
# 3
# Axes(0.511579,0.1;0.236045x0.314727)
# 3
# Axes(0.0644987,0.538745;0.236045x0.314727)
# 0
# Axes(0.539996,0.538745;0.236045x0.314727)
# 0
# Axes(0.0360823,0.1;0.236045x0.314727)
# 0
# Axes(0.511579,0.1;0.236045x0.314727)
# 0
# Axes(0.0644987,0.538745;0.236045x0.314727)
# 2
# Axes(0.539996,0.538745;0.236045x0.314727)
# 2
# Axes(0.0360823,0.1;0.236045x0.314727)
# 2
# Axes(0.511579,0.1;0.236045x0.314727)
# 2
# Axes(0.0644987,0.538745;0.236045x0.314727)
# 4
# Axes(0.539996,0.538745;0.236045x0.314727)
# 4
# Axes(0.0360823,0.1;0.236045x0.314727)
# 4
# Axes(0.511579,0.1;0.236045x0.314727)
# 4
# Axes(0.0644987,0.538745;0.236045x0.314727)
# 7
# ...

# %%
draw_stacked_bar(CA)
# Out:
# None
# None
# None
